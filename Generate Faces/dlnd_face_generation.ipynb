# %% [markdown]
# # Face Generation
#
# In this project, you'll define and train a DCGAN on a dataset of faces. Your goal is to get a generator network to generate *new* images of faces that look as realistic as possible!
#
# The project will be broken down into a series of tasks from **loading in data to defining and training adversarial networks**. At the end of the notebook, you'll be able to visualize the results of your trained Generator to see how it performs; your generated samples should look like fairly realistic faces with small amounts of noise.
#
# ### Get the Data
#
# You'll be using the [CelebFaces Attributes Dataset (CelebA)](http://mmlab.ie.cuhk.edu.hk/projects/CelebA.html) to train your adversarial networks.
#
# This dataset is more complex than the number datasets (like MNIST or SVHN) you've been working with, and so, you should prepare to define deeper networks and train them for a longer time to get good results. It is suggested that you utilize a GPU for training.
#
# ### Pre-processed Data
#
# Since the project's main focus is on building the GANs, we've done *some* of the pre-processing for you. Each of the CelebA images has been cropped to remove parts of the image that don't include a face, then resized down to 64x64x3 NumPy images. Some sample data is show below.
#
# <img src='assets/processed_face_data.png' width=60% />
#
# > If you are working locally, you can download this data [by clicking here](https://s3.amazonaws.com/video.udacity-data.com/topher/2018/November/5be7eb6f_processed-celeba-small/processed-celeba-small.zip)
#
# This is a zip file that you'll need to extract in the home directory of this notebook for further loading and processing. After extracting the data, you should be left with a directory of data `processed_celeba_small/`

# %%
# can comment out after executing
# !unzip processed_celeba_small.zip
# Out:
# Archive:  processed_celeba_small.zip
# replace processed_celeba_small/.DS_Store? [y]es, [n]o, [A]ll, [N]one, [r]ename:

# %%
data_dir = 'processed_celeba_small/'

"""
DON'T MODIFY ANYTHING IN THIS CELL
"""
import pickle as pkl
import matplotlib.pyplot as plt
import numpy as np
import problem_unittests as tests
#import helper

# %matplotlib inline

# %% [markdown]
# ## Visualize the CelebA Data
#
# The [CelebA](http://mmlab.ie.cuhk.edu.hk/projects/CelebA.html) dataset contains over 200,000 celebrity images with annotations. Since you're going to be generating faces, you won't need the annotations, you'll only need the images. Note that these are color images with [3 color channels (RGB)](https://en.wikipedia.org/wiki/Channel_(digital_image)#RGB_Images) each.
#
# ### Pre-process and Load the Data
#
# Since the project's main focus is on building the GANs, we've done *some* of the pre-processing for you. Each of the CelebA images has been cropped to remove parts of the image that don't include a face, then resized down to 64x64x3 NumPy images. This *pre-processed* dataset is a smaller subset of the very large CelebA data.
#
# > There are a few other steps that you'll need to **transform** this data and create a **DataLoader**.
#
# #### Exercise: Complete the following `get_dataloader` function, such that it satisfies these requirements:
#
# * Your images should be square, Tensor images of size `image_size x image_size` in the x and y dimension.
# * Your function should return a DataLoader that shuffles and batches these Tensor images.
#
# #### ImageFolder
#
# To create a dataset given a directory of images, it's recommended that you use PyTorch's [ImageFolder](https://pytorch.org/docs/stable/torchvision/datasets.html#imagefolder) wrapper, with a root directory `processed_celeba_small/` and data transformation passed in.

# %%
# necessary imports
import torch
import torchvision
from torchvision import datasets
from torchvision import transforms
from torch.nn import init

# %%
import os
os.getcwd()
# Out:
# '/home/workspace'

# %%
def get_dataloader(batch_size, image_size, data_dir='processed_celeba_small/'):
    """
    Batch the neural network data using DataLoader
    :param batch_size: The size of each batch; the number of images in a batch
    :param img_size: The square size of the image data (x, y)
    :param data_dir: Directory where image data is located
    :return: DataLoader with batched data
    """
    
    # TODO: Implement function and return a dataloader
    
    transform = transforms.Compose([transforms.Resize(image_size),
                                    transforms.ToTensor()])
    
    num_workers = 0
    
    image_data = datasets.ImageFolder(data_dir, transform = transform)
    dataloader = torch.utils.data.DataLoader(dataset= image_data, batch_size= batch_size, shuffle=True, num_workers= num_workers)
    
    return dataloader

# %% [markdown]
# ## Create a DataLoader
#
# #### Exercise: Create a DataLoader `celeba_train_loader` with appropriate hyperparameters.
#
# Call the above function and create a dataloader to view images.
# * You can decide on any reasonable `batch_size` parameter
# * Your `image_size` **must be** `32`. Resizing the data to a smaller size will make for faster training, while still creating convincing images of faces!

# %%
# Define function hyperparameters
batch_size = 128
img_size = 32

"""
DON'T MODIFY ANYTHING IN THIS CELL THAT IS BELOW THIS LINE
"""
# Call your function and get a dataloader
celeba_train_loader = get_dataloader(batch_size, img_size)

# %% [markdown]
# Next, you can view some images! You should seen square images of somewhat-centered faces.
#
# Note: You'll need to convert the Tensor images into a NumPy type and transpose the dimensions to correctly display an image, suggested `imshow` code is below, but it may not be perfect.

# %%
# helper display function
def imshow(img):
    npimg = img.numpy()
    plt.imshow(np.transpose(npimg, (1, 2, 0)))

"""
DON'T MODIFY ANYTHING IN THIS CELL THAT IS BELOW THIS LINE
"""
# obtain one batch of training images
dataiter = iter(celeba_train_loader)
images, _ = dataiter.next() # _ for no labels

# plot the images in the batch, along with the corresponding labels
fig = plt.figure(figsize=(20, 4))
plot_size=20
for idx in np.arange(plot_size):
    ax = fig.add_subplot(2, plot_size/2, idx+1, xticks=[], yticks=[])
    imshow(images[idx])

# %% [markdown]
# #### Exercise: Pre-process your image data and scale it to a pixel range of -1 to 1
#
# You need to do a bit of pre-processing; you know that the output of a `tanh` activated generator will contain pixel values in a range from -1 to 1, and so, we need to rescale our training images to a range of -1 to 1. (Right now, they are in a range from 0-1.)

# %%
# TODO: Complete the scale function
def scale(x, feature_range=(-1, 1)):
    ''' Scale takes in an image x and returns that image, scaled
       with a feature_range of pixel values from -1 to 1. 
       This function assumes that the input x is already scaled from 0-1.'''
    # assume x is scaled to (0, 1)
    # scale to feature_range and return scaled x
    
    min, max = feature_range
    x = x * (max - min) - max
    
    return x

# %%
"""
DON'T MODIFY ANYTHING IN THIS CELL THAT IS BELOW THIS LINE
"""
# check scaled range
# should be close to -1 to 1
img = images[0]
scaled_img = scale(img)

print('Min: ', scaled_img.min())
print('Max: ', scaled_img.max())
# Out:
# Min:  tensor(-0.8431)
# Max:  tensor(0.9843)

# %%
other_image = images[1]
other_scaled_image = scale(other_image)

print('Min: ', other_scaled_image.min())
print('Max: ', other_scaled_image.max())
# Out:
# Min:  tensor(-0.9922)
# Max:  tensor(0.8275)

# %%
more_other_image = images[2]
more_image_scaled = scale(more_other_image)

print('Min: ', more_image_scaled.min())
print('Max: ', more_image_scaled.max())
# Out:
# Min:  tensor(-0.9451)
# Max:  tensor(0.9451)

# %% [markdown]
# ---
# # Define the Model
#
# A GAN is comprised of two adversarial networks, a discriminator and a generator.
#
# ## Discriminator
#
# Your first task will be to define the discriminator. This is a convolutional classifier like you've built before, only without any maxpooling layers. To deal with this complex data, it's suggested you use a deep network with **normalization**. You are also allowed to create any helper functions that may be useful.
#
# #### Exercise: Complete the Discriminator class
# * The inputs to the discriminator are 32x32x3 tensor images
# * The output should be a single value that will indicate whether a given image is real or fake

# %%
import torch.nn as nn
import torch.nn.functional as F

# %%
def conv(in_channels, out_channels, kernel_size, stride = 2, padding = 1, batch_norm = True):
    
    layers = []
    conv_layer = nn.Conv2d(in_channels, out_channels, kernel_size, stride, padding, bias = False)
    
    layers.append(conv_layer)
    
    if batch_norm:
        layers.append(nn.BatchNorm2d(out_channels))
        
    return nn.Sequential(*layers)

# %%
class Discriminator(nn.Module):

    def __init__(self, conv_dim):
        """
        Initialize the Discriminator Module
        :param conv_dim: The depth of the first convolutional layer
        """
        super(Discriminator, self).__init__()

        # complete init function
        self.conv_dim = conv_dim
        
        # First layer, no batch norm
        self.conv1 = conv(3, self.conv_dim, 4, batch_norm=False)
        
        self.conv2 = conv(self.conv_dim, self.conv_dim*2, 4)
        
        self.conv3 = conv(self.conv_dim*2, self.conv_dim*4, 4)
        
        self.fc = nn.Linear(self.conv_dim*4*4*4, 1)

    def forward(self, x):
        """
        Forward propagation of the neural network
        :param x: The input to the neural network     
        :return: Discriminator logits; the output of the neural network
        """
        # define feedforward behavior
        
        x = F.leaky_relu(self.conv1(x), 0.2)
        x = F.leaky_relu(self.conv2(x), 0.2)
        x = F.leaky_relu(self.conv3(x), 0.2)
        
        x = x.view(-1, self.conv_dim*4*4*4)
        x = self.fc(x)
        
        
        return x


"""
DON'T MODIFY ANYTHING IN THIS CELL THAT IS BELOW THIS LINE
"""
tests.test_discriminator(Discriminator)
# Out:
# Tests Passed

# %% [markdown]
# ## Generator
#
# The generator should upsample an input and generate a *new* image of the same size as our training data `32x32x3`. This should be mostly transpose convolutional layers with normalization applied to the outputs.
#
# #### Exercise: Complete the Generator class
# * The inputs to the generator are vectors of some length `z_size`
# * The output should be a image of shape `32x32x3`

# %%
def deconv(in_channels, out_channels, kernel_size, stride = 2, padding = 1, batch_norm = True):
    
    layers = []
    transpose_conv_layer = nn.ConvTranspose2d(in_channels, out_channels, kernel_size, stride, padding, bias = False)
    
    layers.append(transpose_conv_layer)
    
    if batch_norm:
        layers.append(nn.BatchNorm2d(out_channels))
        
    return nn.Sequential(*layers)

# %%
class Generator(nn.Module):
    
    def __init__(self, z_size, conv_dim):
        """
        Initialize the Generator Module
        :param z_size: The length of the input latent vector, z
        :param conv_dim: The depth of the inputs to the *last* transpose convolutional layer
        """
        super(Generator, self).__init__()

        # complete init function
        
        self.z_size = z_size
        self.conv_dim = conv_dim
        
        
        self.fc = nn.Linear(z_size, 4 * 4 * conv_dim*4)
        
        self.t_conv1 = deconv(conv_dim*4, conv_dim*2, 4)
        self.t_conv2 = deconv(conv_dim*2, conv_dim, 4)
        self.t_conv3 = deconv(conv_dim, 3, 4, batch_norm = False)
        

    def forward(self, x):
        """
        Forward propagation of the neural network
        :param x: The input to the neural network     
        :return: A 32x32x3 Tensor image as output
        """
        # define feedforward behavior
        x = self.fc(x)
        x = x.view(-1, self.conv_dim*4, 4, 4)
        
        x = F.relu(self.t_conv1(x))
        x = F.relu(self.t_conv2(x))
        x = F.tanh(self.t_conv3(x))        
        
        return x

"""
DON'T MODIFY ANYTHING IN THIS CELL THAT IS BELOW THIS LINE
"""
tests.test_generator(Generator)
# Out:
# Tests Passed

# %% [markdown]
# ## Initialize the weights of your networks
#
# To help your models converge, you should initialize the weights of the convolutional and linear layers in your model. From reading the [original DCGAN paper](https://arxiv.org/pdf/1511.06434.pdf), they say:
# > All weights were initialized from a zero-centered Normal distribution with standard deviation 0.02.
#
# So, your next task will be to define a weight initialization function that does just this!
#
# You can refer back to the lesson on weight initialization or even consult existing model code, such as that from [the `networks.py` file in CycleGAN Github repository](https://github.com/junyanz/pytorch-CycleGAN-and-pix2pix/blob/master/models/networks.py) to help you complete this function.
#
# #### Exercise: Complete the weight initialization function
#
# * This should initialize only **convolutional** and **linear** layers
# * Initialize the weights to a normal distribution, centered around 0, with a standard deviation of 0.02.
# * The bias terms, if they exist, may be left alone or set to 0.

# %%
def weights_init_normal(m):
    """
    Applies initial weights to certain layers in a model .
    The weights are taken from a normal distribution 
    with mean = 0, std dev = 0.02.
    :param m: A module or layer in a network    
    """
    # classname will be something like:
    # `Conv`, `BatchNorm2d`, `Linear`, etc.
    classname = m.__class__.__name__
    
    # TODO: Apply initial weights to convolutional and linear layers
    
    if hasattr(m, 'weight') and (classname.find('Conv') != -1 or classname.find('Linear') != -1):
        init.normal_(m.weight.data, 0.0, 0.02)

# %% [markdown]
# ## Build complete network
#
# Define your models' hyperparameters and instantiate the discriminator and generator from the classes defined above. Make sure you've passed in the correct input arguments.

# %%
"""
DON'T MODIFY ANYTHING IN THIS CELL THAT IS BELOW THIS LINE
"""
def build_network(d_conv_dim, g_conv_dim, z_size):
    # define discriminator and generator
    D = Discriminator(d_conv_dim)
    G = Generator(z_size=z_size, conv_dim=g_conv_dim)

    # initialize model weights
    D.apply(weights_init_normal)
    G.apply(weights_init_normal)

    print(D)
    print()
    print(G)
    
    return D, G

# %% [markdown]
# #### Exercise: Define model hyperparameters

# %%
# Define model hyperparams
d_conv_dim = 32
g_conv_dim = 32
z_size = 100

"""
DON'T MODIFY ANYTHING IN THIS CELL THAT IS BELOW THIS LINE
"""
D, G = build_network(d_conv_dim, g_conv_dim, z_size)
# Out:
# Discriminator(
#   (conv1): Sequential(
#     (0): Conv2d(3, 32, kernel_size=(4, 4), stride=(2, 2), padding=(1, 1), bias=False)
#   )
#   (conv2): Sequential(
#     (0): Conv2d(32, 64, kernel_size=(4, 4), stride=(2, 2), padding=(1, 1), bias=False)
#     (1): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   )
#   (conv3): Sequential(
#     (0): Conv2d(64, 128, kernel_size=(4, 4), stride=(2, 2), padding=(1, 1), bias=False)
#     (1): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   )
#   (fc): Linear(in_features=2048, out_features=1, bias=True)
# )
#
# Generator(
#   (fc): Linear(in_features=100, out_features=2048, bias=True)
#   (t_conv1): Sequential(
#     (0): ConvTranspose2d(128, 64, kernel_size=(4, 4), stride=(2, 2), padding=(1, 1), bias=False)
#     (1): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   )
#   (t_conv2): Sequential(
#     (0): ConvTranspose2d(64, 32, kernel_size=(4, 4), stride=(2, 2), padding=(1, 1), bias=False)
#     (1): BatchNorm2d(32, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   )
#   (t_conv3): Sequential(
#     (0): ConvTranspose2d(32, 3, kernel_size=(4, 4), stride=(2, 2), padding=(1, 1), bias=False)
#   )
# )

# %% [markdown]
# ### Training on GPU
#
# Check if you can train on GPU. Here, we'll set this as a boolean variable `train_on_gpu`. Later, you'll be responsible for making sure that
# >* Models,
# * Model inputs, and
# * Loss function arguments
#
# Are moved to GPU, where appropriate.

# %%
"""
DON'T MODIFY ANYTHING IN THIS CELL
"""
import torch

# Check for a GPU
train_on_gpu = torch.cuda.is_available()
if not train_on_gpu:
    print('No GPU found. Please use a GPU to train your neural network.')
else:
    print('Training on GPU!')
# Out:
# Training on GPU!

# %% [markdown]
# ---
# ## Discriminator and Generator Losses
#
# Now we need to calculate the losses for both types of adversarial networks.
#
# ### Discriminator Losses
#
# > * For the discriminator, the total loss is the sum of the losses for real and fake images, `d_loss = d_real_loss + d_fake_loss`.
# * Remember that we want the discriminator to output 1 for real images and 0 for fake images, so we need to set up the losses to reflect that.
#
#
# ### Generator Loss
#
# The generator loss will look similar only with flipped labels. The generator's goal is to get the discriminator to *think* its generated images are *real*.
#
# #### Exercise: Complete real and fake loss functions
#
# **You may choose to use either cross entropy or a least squares error loss to complete the following `real_loss` and `fake_loss` functions.**

# %%
def real_loss(D_out, smooth=False):
    '''Calculates how close discriminator outputs are to being real.
       param, D_out: discriminator logits
       return: real loss'''
    
    real_loss = torch.mean((D_out - 0.9)**2)
    
    return real_loss

def fake_loss(D_out):
    '''Calculates how close discriminator outputs are to being fake.
       param, D_out: discriminator logits
       return: fake loss'''
    fake_loss = torch.mean((D_out)**2)
    
    return fake_loss

# %% [markdown]
# ## Optimizers
#
# #### Exercise: Define optimizers for your Discriminator (D) and Generator (G)
#
# Define optimizers for your models with appropriate hyperparameters.

# %%
import torch.optim as optim

lr = 0.0002
beta1 = 0.5
beta2 = 0.999

# Create optimizers for the discriminator D and generator G
d_optimizer = optim.Adam(D.parameters(), lr, [beta1, beta2])
g_optimizer = optim.Adam(G.parameters(), lr, [beta1, beta2])

# %% [markdown]
# ---
# ## Training
#
# Training will involve alternating between training the discriminator and the generator. You'll use your functions `real_loss` and `fake_loss` to help you calculate the discriminator losses.
#
# * You should train the discriminator by alternating on real and fake images
# * Then the generator, which tries to trick the discriminator and should have an opposing loss function
#
#
# #### Saving Samples
#
# You've been given some code to print out some loss statistics and save some generated "fake" samples.

# %% [markdown]
# #### Exercise: Complete the training function
#
# Keep in mind that, if you've moved your models to GPU, you'll also have to move any model inputs to GPU.

# %%
def train(D, G, n_epochs, print_every=50):
    '''Trains adversarial networks for some number of epochs
       param, D: the discriminator network
       param, G: the generator network
       param, n_epochs: number of epochs to train for
       param, print_every: when to print and record the models' losses
       return: D and G losses'''
    
    # move models to GPU
    if train_on_gpu:
        D.cuda()
        G.cuda()

    # keep track of loss and generated, "fake" samples
    samples = []
    losses = []

    # Get some fixed data for sampling. These are images that are held
    # constant throughout training, and allow us to inspect the model's performance
    sample_size=16
    fixed_z = np.random.uniform(-1, 1, size=(sample_size, z_size))
    fixed_z = torch.from_numpy(fixed_z).float()
    # move z to GPU if available
    if train_on_gpu:
        fixed_z = fixed_z.cuda()

    # epoch training loop
    for epoch in range(n_epochs):

        # batch training loop
        for batch_i, (real_images, _) in enumerate(celeba_train_loader):

            batch_size = real_images.size(0)
            real_images = scale(real_images)

            # ===============================================
            #         YOUR CODE HERE: TRAIN THE NETWORKS
            # ===============================================
            
            # 1. Train the discriminator on real and fake images
            
            if train_on_gpu:
                real_images = real_images.cuda()
                
            d_optimizer.zero_grad()
            
            d_real_loss = real_loss(D(real_images))
            
            #Generating fake images
            z = np.random.uniform(-1, 1, size=(batch_size, z_size))
            z = torch.from_numpy(z).float()
            
            if train_on_gpu:
                z = z.cuda()
                
            fake_images = G(z)
            
            d_fake_loss = fake_loss(D(fake_images))
            
            d_loss = d_real_loss + d_fake_loss
            d_loss.backward()
            d_optimizer.step()

            # 2. Train the generator with an adversarial loss
            g_optimizer.zero_grad()
            
            z = np.random.uniform(-1, 1, size=(batch_size, z_size))
            z = torch.from_numpy(z).float()
            
            if train_on_gpu:
                z = z.cuda()
            fake_images = G(z)
            
            g_loss = real_loss(D(fake_images))
            g_loss.backward()
            g_optimizer.step()
            
            
            # ===============================================
            #              END OF YOUR CODE
            # ===============================================

            # Print some loss stats
            if batch_i % print_every == 0:
                # append discriminator loss and generator loss
                losses.append((d_loss.item(), g_loss.item()))
                # print discriminator and generator loss
                print('Epoch [{:5d}/{:5d}] | d_loss: {:6.4f} | g_loss: {:6.4f}'.format(
                        epoch+1, n_epochs, d_loss.item(), g_loss.item()))


        ## AFTER EACH EPOCH##    
        # this code assumes your generator is named G, feel free to change the name
        # generate and save sample, fake images
        G.eval() # for generating samples
        samples_z = G(fixed_z)
        samples.append(samples_z)
        G.train() # back to training mode

    # Save training generator samples
    with open('train_samples.pkl', 'wb') as f:
        pkl.dump(samples, f)
    
    # finally return losses
    return losses

# %% [markdown]
# Set your number of training epochs and train your GAN!

# %%
# set number of epochs 
n_epochs = 50


"""
DON'T MODIFY ANYTHING IN THIS CELL
"""
# call training function
losses = train(D, G, n_epochs=n_epochs)
# Out:
# Epoch [    1/   50] | d_loss: 0.6192 | g_loss: 0.7137
# Epoch [    1/   50] | d_loss: 0.1300 | g_loss: 1.5515
# Epoch [    1/   50] | d_loss: 0.0378 | g_loss: 1.2566
# Epoch [    1/   50] | d_loss: 0.1800 | g_loss: 1.7983
# Epoch [    1/   50] | d_loss: 0.2519 | g_loss: 2.0996
# Epoch [    1/   50] | d_loss: 0.0443 | g_loss: 0.7145
# Epoch [    1/   50] | d_loss: 0.0462 | g_loss: 0.8917
# Epoch [    1/   50] | d_loss: 0.0366 | g_loss: 0.5438
# Epoch [    1/   50] | d_loss: 0.1840 | g_loss: 1.2985
# Epoch [    1/   50] | d_loss: 0.0671 | g_loss: 0.9323
# Epoch [    1/   50] | d_loss: 0.0629 | g_loss: 0.8410
# Epoch [    1/   50] | d_loss: 0.0517 | g_loss: 0.7776
# Epoch [    1/   50] | d_loss: 0.0926 | g_loss: 0.8020
# Epoch [    1/   50] | d_loss: 0.7388 | g_loss: 1.6966
# Epoch [    1/   50] | d_loss: 0.7047 | g_loss: 2.4544
# Epoch [    2/   50] | d_loss: 0.9457 | g_loss: 0.0877
# Epoch [    2/   50] | d_loss: 0.2555 | g_loss: 0.3118
# Epoch [    2/   50] | d_loss: 0.1473 | g_loss: 0.7301
# Epoch [    2/   50] | d_loss: 0.1192 | g_loss: 0.4209
# Epoch [    2/   50] | d_loss: 0.1436 | g_loss: 0.6372
# Epoch [    2/   50] | d_loss: 0.1549 | g_loss: 0.7213
# Epoch [    2/   50] | d_loss: 0.3234 | g_loss: 1.3007
# Epoch [    2/   50] | d_loss: 0.1766 | g_loss: 0.5598
# Epoch [    2/   50] | d_loss: 0.2173 | g_loss: 0.7937
# Epoch [    2/   50] | d_loss: 0.1857 | g_loss: 0.7465
# Epoch [    2/   50] | d_loss: 0.2654 | g_loss: 0.5909
# Epoch [    2/   50] | d_loss: 0.2022 | g_loss: 0.8434
# Epoch [    2/   50] | d_loss: 0.3289 | g_loss: 0.4870
# Epoch [    2/   50] | d_loss: 0.5926 | g_loss: 1.3785
# Epoch [    2/   50] | d_loss: 0.2744 | g_loss: 0.4446
# Epoch [    3/   50] | d_loss: 0.2875 | g_loss: 0.7600
# Epoch [    3/   50] | d_loss: 0.2579 | g_loss: 0.3549
# Epoch [    3/   50] | d_loss: 0.2474 | g_loss: 0.4574
# Epoch [    3/   50] | d_loss: 0.3107 | g_loss: 0.2432
# Epoch [    3/   50] | d_loss: 0.1930 | g_loss: 0.5481
# Epoch [    3/   50] | d_loss: 0.3025 | g_loss: 0.4028
# Epoch [    3/   50] | d_loss: 0.3022 | g_loss: 0.2988
# Epoch [    3/   50] | d_loss: 0.3113 | g_loss: 0.2596
# Epoch [    3/   50] | d_loss: 0.2597 | g_loss: 0.3283
# Epoch [    3/   50] | d_loss: 0.2935 | g_loss: 0.3446
# Epoch [    3/   50] | d_loss: 0.2758 | g_loss: 0.2545
# Epoch [    3/   50] | d_loss: 0.2580 | g_loss: 0.6883
# Epoch [    3/   50] | d_loss: 0.2244 | g_loss: 0.4137
# Epoch [    3/   50] | d_loss: 0.2765 | g_loss: 0.6135
# Epoch [    3/   50] | d_loss: 0.2491 | g_loss: 0.4383
# Epoch [    4/   50] | d_loss: 0.2660 | g_loss: 0.3973
# Epoch [    4/   50] | d_loss: 0.3241 | g_loss: 0.4748
# Epoch [    4/   50] | d_loss: 0.4917 | g_loss: 0.5437
# Epoch [    4/   50] | d_loss: 0.4738 | g_loss: 0.1600
# Epoch [    4/   50] | d_loss: 0.4195 | g_loss: 0.5850
# Epoch [    4/   50] | d_loss: 0.2123 | g_loss: 0.5406
# Epoch [    4/   50] | d_loss: 0.2702 | g_loss: 0.4844
# Epoch [    4/   50] | d_loss: 0.2643 | g_loss: 0.3655
# Epoch [    4/   50] | d_loss: 0.4371 | g_loss: 0.7106
# Epoch [    4/   50] | d_loss: 0.2497 | g_loss: 0.2526
# Epoch [    4/   50] | d_loss: 0.2504 | g_loss: 0.4563
# Epoch [    4/   50] | d_loss: 0.2639 | g_loss: 0.4048
# Epoch [    4/   50] | d_loss: 0.2793 | g_loss: 0.5032
# Epoch [    4/   50] | d_loss: 0.3137 | g_loss: 0.4213
# Epoch [    4/   50] | d_loss: 0.2297 | g_loss: 0.4404
# Epoch [    5/   50] | d_loss: 0.3327 | g_loss: 0.3521
# Epoch [    5/   50] | d_loss: 0.2491 | g_loss: 0.4564
# Epoch [    5/   50] | d_loss: 0.2636 | g_loss: 0.4024
# Epoch [    5/   50] | d_loss: 0.2775 | g_loss: 0.3291
# Epoch [    5/   50] | d_loss: 0.3143 | g_loss: 0.4061
# Epoch [    5/   50] | d_loss: 0.2215 | g_loss: 0.2916
# Epoch [    5/   50] | d_loss: 0.2609 | g_loss: 0.3841
# Epoch [    5/   50] | d_loss: 0.2558 | g_loss: 0.3958
# Epoch [    5/   50] | d_loss: 0.3687 | g_loss: 0.2847
# Epoch [    5/   50] | d_loss: 0.2740 | g_loss: 0.3532
# Epoch [    5/   50] | d_loss: 0.2932 | g_loss: 0.5282
# Epoch [    5/   50] | d_loss: 0.2322 | g_loss: 0.4969
# Epoch [    5/   50] | d_loss: 0.2972 | g_loss: 0.2927
# Epoch [    5/   50] | d_loss: 0.3615 | g_loss: 0.3245
# Epoch [    5/   50] | d_loss: 0.2957 | g_loss: 0.4115
# Epoch [    6/   50] | d_loss: 0.2869 | g_loss: 0.3464
# Epoch [    6/   50] | d_loss: 0.2457 | g_loss: 0.5653
# Epoch [    6/   50] | d_loss: 0.3225 | g_loss: 0.5520
# Epoch [    6/   50] | d_loss: 0.3169 | g_loss: 0.2189
# Epoch [    6/   50] | d_loss: 0.3307 | g_loss: 0.6522
# Epoch [    6/   50] | d_loss: 0.3077 | g_loss: 0.3056
# Epoch [    6/   50] | d_loss: 0.3057 | g_loss: 0.2537
# Epoch [    6/   50] | d_loss: 0.3120 | g_loss: 0.2830
# Epoch [    6/   50] | d_loss: 0.2441 | g_loss: 0.4776
# Epoch [    6/   50] | d_loss: 2.2858 | g_loss: 1.5706
# Epoch [    6/   50] | d_loss: 0.3343 | g_loss: 0.3263
# Epoch [    6/   50] | d_loss: 0.2630 | g_loss: 0.4903
# Epoch [    6/   50] | d_loss: 0.2141 | g_loss: 0.4510
# Epoch [    6/   50] | d_loss: 0.3297 | g_loss: 0.4270
# Epoch [    6/   50] | d_loss: 0.2795 | g_loss: 0.5383
# Epoch [    7/   50] | d_loss: 0.2675 | g_loss: 0.4305
# Epoch [    7/   50] | d_loss: 0.2984 | g_loss: 0.2939
# Epoch [    7/   50] | d_loss: 0.2752 | g_loss: 0.5080
# Epoch [    7/   50] | d_loss: 0.3436 | g_loss: 0.4105
# Epoch [    7/   50] | d_loss: 0.2274 | g_loss: 0.3361
# Epoch [    7/   50] | d_loss: 0.3547 | g_loss: 0.3211
# Epoch [    7/   50] | d_loss: 0.2490 | g_loss: 0.4351
# Epoch [    7/   50] | d_loss: 0.2490 | g_loss: 0.3225
# Epoch [    7/   50] | d_loss: 0.2172 | g_loss: 0.5969
# Epoch [    7/   50] | d_loss: 0.2301 | g_loss: 0.3301
# Epoch [    7/   50] | d_loss: 0.2616 | g_loss: 0.7695
# Epoch [    7/   50] | d_loss: 0.2786 | g_loss: 0.4516
# Epoch [    7/   50] | d_loss: 0.3361 | g_loss: 0.2913
# Epoch [    7/   50] | d_loss: 0.2985 | g_loss: 0.3406
# Epoch [    7/   50] | d_loss: 0.4111 | g_loss: 0.4259
# Epoch [    8/   50] | d_loss: 0.3863 | g_loss: 0.3285
# Epoch [    8/   50] | d_loss: 0.1963 | g_loss: 0.4037
# Epoch [    8/   50] | d_loss: 0.3358 | g_loss: 0.4989
# Epoch [    8/   50] | d_loss: 0.1985 | g_loss: 0.3479
# Epoch [    8/   50] | d_loss: 0.1663 | g_loss: 0.6784
# Epoch [    8/   50] | d_loss: 0.2028 | g_loss: 0.6347
# Epoch [    8/   50] | d_loss: 0.2357 | g_loss: 0.3512
# Epoch [    8/   50] | d_loss: 0.2912 | g_loss: 0.5699
# Epoch [    8/   50] | d_loss: 0.2655 | g_loss: 0.4599
# Epoch [    8/   50] | d_loss: 0.2565 | g_loss: 0.2509
# Epoch [    8/   50] | d_loss: 0.2413 | g_loss: 0.3916
# Epoch [    8/   50] | d_loss: 0.3823 | g_loss: 0.3961
# Epoch [    8/   50] | d_loss: 0.2140 | g_loss: 0.5476
# Epoch [    8/   50] | d_loss: 0.2788 | g_loss: 0.3501
# Epoch [    8/   50] | d_loss: 0.2462 | g_loss: 0.4468
# Epoch [    9/   50] | d_loss: 0.2938 | g_loss: 0.4208
# Epoch [    9/   50] | d_loss: 0.3375 | g_loss: 0.2250
# Epoch [    9/   50] | d_loss: 0.2380 | g_loss: 0.8463
# Epoch [    9/   50] | d_loss: 0.2491 | g_loss: 0.3498
# Epoch [    9/   50] | d_loss: 0.3363 | g_loss: 0.2554
# Epoch [    9/   50] | d_loss: 0.2600 | g_loss: 0.3667
# Epoch [    9/   50] | d_loss: 0.3292 | g_loss: 0.4089
# Epoch [    9/   50] | d_loss: 0.3999 | g_loss: 0.7157
# Epoch [    9/   50] | d_loss: 0.2976 | g_loss: 0.3984
# Epoch [    9/   50] | d_loss: 0.2363 | g_loss: 0.4199
# Epoch [    9/   50] | d_loss: 0.2321 | g_loss: 0.3615
# Epoch [    9/   50] | d_loss: 0.2284 | g_loss: 0.3086
# Epoch [    9/   50] | d_loss: 0.2634 | g_loss: 0.2790
# Epoch [    9/   50] | d_loss: 0.2822 | g_loss: 0.2820
# Epoch [    9/   50] | d_loss: 0.2664 | g_loss: 0.3531
# Epoch [   10/   50] | d_loss: 0.2388 | g_loss: 0.4539
# Epoch [   10/   50] | d_loss: 0.2452 | g_loss: 0.4527
# Epoch [   10/   50] | d_loss: 0.2679 | g_loss: 0.3967
# Epoch [   10/   50] | d_loss: 0.2667 | g_loss: 0.5251
# Epoch [   10/   50] | d_loss: 0.4139 | g_loss: 0.3935
# Epoch [   10/   50] | d_loss: 0.2987 | g_loss: 0.4348
# Epoch [   10/   50] | d_loss: 0.2158 | g_loss: 0.5126
# Epoch [   10/   50] | d_loss: 0.2182 | g_loss: 0.4096
# Epoch [   10/   50] | d_loss: 0.2891 | g_loss: 0.4121
# Epoch [   10/   50] | d_loss: 0.2645 | g_loss: 0.3868
# Epoch [   10/   50] | d_loss: 0.2243 | g_loss: 0.5422
# Epoch [   10/   50] | d_loss: 0.2525 | g_loss: 0.4945
# Epoch [   10/   50] | d_loss: 0.2173 | g_loss: 0.3586
# Epoch [   10/   50] | d_loss: 0.2475 | g_loss: 0.3313
# Epoch [   10/   50] | d_loss: 0.3327 | g_loss: 0.3131
# Epoch [   11/   50] | d_loss: 0.3923 | g_loss: 0.4007
# Epoch [   11/   50] | d_loss: 0.1737 | g_loss: 0.6422
# Epoch [   11/   50] | d_loss: 0.2218 | g_loss: 0.5631
# Epoch [   11/   50] | d_loss: 0.3584 | g_loss: 0.3422
# Epoch [   11/   50] | d_loss: 0.2290 | g_loss: 0.5072
# Epoch [   11/   50] | d_loss: 0.2131 | g_loss: 0.4313
# Epoch [   11/   50] | d_loss: 0.2357 | g_loss: 0.4855
# Epoch [   11/   50] | d_loss: 0.2783 | g_loss: 0.2496
# Epoch [   11/   50] | d_loss: 0.2831 | g_loss: 0.5888
# Epoch [   11/   50] | d_loss: 0.2615 | g_loss: 0.3378
# Epoch [   11/   50] | d_loss: 0.3371 | g_loss: 0.5171
# Epoch [   11/   50] | d_loss: 0.2347 | g_loss: 0.6083
# Epoch [   11/   50] | d_loss: 0.4024 | g_loss: 0.8890
# Epoch [   11/   50] | d_loss: 0.2394 | g_loss: 0.3159
# Epoch [   11/   50] | d_loss: 0.2096 | g_loss: 0.5967
# Epoch [   12/   50] | d_loss: 0.2110 | g_loss: 0.3847
# Epoch [   12/   50] | d_loss: 0.2752 | g_loss: 0.3575
# Epoch [   12/   50] | d_loss: 0.2090 | g_loss: 0.5119
# Epoch [   12/   50] | d_loss: 0.2288 | g_loss: 0.4936
# Epoch [   12/   50] | d_loss: 0.2616 | g_loss: 0.2857
# Epoch [   12/   50] | d_loss: 0.2512 | g_loss: 0.4341
# Epoch [   12/   50] | d_loss: 0.2336 | g_loss: 0.4131
# Epoch [   12/   50] | d_loss: 0.2566 | g_loss: 0.2663
# Epoch [   12/   50] | d_loss: 0.2186 | g_loss: 0.3619
# Epoch [   12/   50] | d_loss: 0.2346 | g_loss: 0.5460
# Epoch [   12/   50] | d_loss: 0.2939 | g_loss: 0.6347
# Epoch [   12/   50] | d_loss: 0.2650 | g_loss: 0.3435
# Epoch [   12/   50] | d_loss: 0.2589 | g_loss: 0.5580
# Epoch [   12/   50] | d_loss: 0.2520 | g_loss: 0.5443
# Epoch [   12/   50] | d_loss: 0.5342 | g_loss: 0.1998
# Epoch [   13/   50] | d_loss: 0.5141 | g_loss: 0.1990
# Epoch [   13/   50] | d_loss: 0.2912 | g_loss: 0.3359
# Epoch [   13/   50] | d_loss: 0.2785 | g_loss: 0.3003
# Epoch [   13/   50] | d_loss: 0.1965 | g_loss: 0.3706
# Epoch [   13/   50] | d_loss: 0.2906 | g_loss: 0.2880
# Epoch [   13/   50] | d_loss: 0.2316 | g_loss: 0.4219
# Epoch [   13/   50] | d_loss: 0.2713 | g_loss: 0.3496
# Epoch [   13/   50] | d_loss: 0.4222 | g_loss: 0.1927
# Epoch [   13/   50] | d_loss: 0.2912 | g_loss: 0.5966
# Epoch [   13/   50] | d_loss: 0.3133 | g_loss: 0.3629
# Epoch [   13/   50] | d_loss: 0.2480 | g_loss: 0.3894
# Epoch [   13/   50] | d_loss: 0.2192 | g_loss: 0.2691
# Epoch [   13/   50] | d_loss: 0.2242 | g_loss: 0.3996
# Epoch [   13/   50] | d_loss: 0.2262 | g_loss: 0.6477
# Epoch [   13/   50] | d_loss: 0.2382 | g_loss: 0.3834
# Epoch [   14/   50] | d_loss: 0.3467 | g_loss: 0.6575
# Epoch [   14/   50] | d_loss: 0.2178 | g_loss: 0.5220
# Epoch [   14/   50] | d_loss: 0.2974 | g_loss: 0.2817
# Epoch [   14/   50] | d_loss: 0.2851 | g_loss: 0.4433
# Epoch [   14/   50] | d_loss: 0.2846 | g_loss: 0.0797
# Epoch [   14/   50] | d_loss: 0.2552 | g_loss: 0.4641
# Epoch [   14/   50] | d_loss: 0.2245 | g_loss: 0.5464
# Epoch [   14/   50] | d_loss: 0.2800 | g_loss: 0.4145
# Epoch [   14/   50] | d_loss: 0.2313 | g_loss: 0.4855
# Epoch [   14/   50] | d_loss: 0.2401 | g_loss: 0.5257
# Epoch [   14/   50] | d_loss: 0.2425 | g_loss: 0.6807
# Epoch [   14/   50] | d_loss: 0.2282 | g_loss: 0.3940
# Epoch [   14/   50] | d_loss: 0.2338 | g_loss: 0.5526
# Epoch [   14/   50] | d_loss: 0.1572 | g_loss: 0.2426
# Epoch [   14/   50] | d_loss: 0.2744 | g_loss: 0.3927
# Epoch [   15/   50] | d_loss: 0.2310 | g_loss: 0.4767
# Epoch [   15/   50] | d_loss: 0.2641 | g_loss: 0.2815
# Epoch [   15/   50] | d_loss: 0.2781 | g_loss: 0.6159
# Epoch [   15/   50] | d_loss: 0.2449 | g_loss: 0.4474
# Epoch [   15/   50] | d_loss: 0.2010 | g_loss: 0.6113
# Epoch [   15/   50] | d_loss: 0.3017 | g_loss: 0.7150
# Epoch [   15/   50] | d_loss: 0.1430 | g_loss: 0.8309
# Epoch [   15/   50] | d_loss: 0.2590 | g_loss: 0.5344
# Epoch [   15/   50] | d_loss: 0.2163 | g_loss: 0.4488
# Epoch [   15/   50] | d_loss: 0.2846 | g_loss: 0.3402
# Epoch [   15/   50] | d_loss: 0.2072 | g_loss: 0.4285
# Epoch [   15/   50] | d_loss: 0.2718 | g_loss: 0.3211
# Epoch [   15/   50] | d_loss: 0.2514 | g_loss: 0.5141
# Epoch [   15/   50] | d_loss: 0.2236 | g_loss: 0.2739
# Epoch [   15/   50] | d_loss: 0.2877 | g_loss: 0.2425
# Epoch [   16/   50] | d_loss: 0.4826 | g_loss: 0.6888
# Epoch [   16/   50] | d_loss: 0.2485 | g_loss: 0.2905
# Epoch [   16/   50] | d_loss: 0.4037 | g_loss: 0.1725
# Epoch [   16/   50] | d_loss: 0.1917 | g_loss: 0.4205
# Epoch [   16/   50] | d_loss: 0.4841 | g_loss: 0.1308
# Epoch [   16/   50] | d_loss: 0.2106 | g_loss: 0.3202
# Epoch [   16/   50] | d_loss: 0.1919 | g_loss: 0.6213
# Epoch [   16/   50] | d_loss: 0.2905 | g_loss: 0.3622
# Epoch [   16/   50] | d_loss: 0.1466 | g_loss: 0.4300
# Epoch [   16/   50] | d_loss: 0.1714 | g_loss: 0.5558
# Epoch [   16/   50] | d_loss: 0.1623 | g_loss: 0.5566
# Epoch [   16/   50] | d_loss: 0.3879 | g_loss: 0.3563
# Epoch [   16/   50] | d_loss: 0.2025 | g_loss: 0.3939
# Epoch [   16/   50] | d_loss: 0.1799 | g_loss: 0.5855
# Epoch [   16/   50] | d_loss: 0.2934 | g_loss: 0.2863
# Epoch [   17/   50] | d_loss: 0.2277 | g_loss: 0.5684
# Epoch [   17/   50] | d_loss: 0.2270 | g_loss: 0.4764
# Epoch [   17/   50] | d_loss: 0.2057 | g_loss: 0.4545
# Epoch [   17/   50] | d_loss: 0.1821 | g_loss: 0.5341
# Epoch [   17/   50] | d_loss: 0.1864 | g_loss: 0.4855
# Epoch [   17/   50] | d_loss: 0.2689 | g_loss: 0.5257
# Epoch [   17/   50] | d_loss: 0.3039 | g_loss: 0.2339
# Epoch [   17/   50] | d_loss: 0.2430 | g_loss: 0.4355
# Epoch [   17/   50] | d_loss: 0.1828 | g_loss: 0.2816
# Epoch [   17/   50] | d_loss: 0.1936 | g_loss: 0.5873
# Epoch [   17/   50] | d_loss: 0.1466 | g_loss: 0.4657
# Epoch [   17/   50] | d_loss: 0.2298 | g_loss: 0.2569
# Epoch [   17/   50] | d_loss: 0.2346 | g_loss: 0.7607
# Epoch [   17/   50] | d_loss: 0.2188 | g_loss: 0.4115
# Epoch [   17/   50] | d_loss: 0.2693 | g_loss: 0.3827
# Epoch [   18/   50] | d_loss: 0.1987 | g_loss: 0.2668
# Epoch [   18/   50] | d_loss: 0.1658 | g_loss: 0.5339
# Epoch [   18/   50] | d_loss: 0.2040 | g_loss: 0.7537
# Epoch [   18/   50] | d_loss: 0.2335 | g_loss: 0.4472
# Epoch [   18/   50] | d_loss: 0.1825 | g_loss: 0.5021
# Epoch [   18/   50] | d_loss: 0.1620 | g_loss: 0.4241
# Epoch [   18/   50] | d_loss: 0.1610 | g_loss: 0.7120
# Epoch [   18/   50] | d_loss: 0.2278 | g_loss: 0.3826
# Epoch [   18/   50] | d_loss: 0.4607 | g_loss: 0.2308
# Epoch [   18/   50] | d_loss: 0.4412 | g_loss: 0.2174
# Epoch [   18/   50] | d_loss: 0.5249 | g_loss: 0.2052
# Epoch [   18/   50] | d_loss: 0.4188 | g_loss: 0.2507
# Epoch [   18/   50] | d_loss: 0.4564 | g_loss: 0.1910
# Epoch [   18/   50] | d_loss: 0.4628 | g_loss: 0.2089
# Epoch [   18/   50] | d_loss: 0.4435 | g_loss: 0.2236
# Epoch [   19/   50] | d_loss: 0.4280 | g_loss: 0.2094
# Epoch [   19/   50] | d_loss: 0.4222 | g_loss: 0.2295
# Epoch [   19/   50] | d_loss: 0.4591 | g_loss: 0.2127
# Epoch [   19/   50] | d_loss: 0.4130 | g_loss: 0.2014
# Epoch [   19/   50] | d_loss: 0.4291 | g_loss: 0.2075
# Epoch [   19/   50] | d_loss: 0.4205 | g_loss: 0.2103
# Epoch [   19/   50] | d_loss: 0.4143 | g_loss: 0.2123
# Epoch [   19/   50] | d_loss: 0.4358 | g_loss: 0.2035
# Epoch [   19/   50] | d_loss: 0.4360 | g_loss: 0.2232
# Epoch [   19/   50] | d_loss: 0.4268 | g_loss: 0.2029
# Epoch [   19/   50] | d_loss: 0.4091 | g_loss: 0.2347
# Epoch [   19/   50] | d_loss: 0.4352 | g_loss: 0.2204
# Epoch [   19/   50] | d_loss: 0.4100 | g_loss: 0.2071
# Epoch [   19/   50] | d_loss: 0.4073 | g_loss: 0.1956
# Epoch [   19/   50] | d_loss: 0.4062 | g_loss: 0.2214
# Epoch [   20/   50] | d_loss: 0.4238 | g_loss: 0.2192
# Epoch [   20/   50] | d_loss: 0.4173 | g_loss: 0.2171
# Epoch [   20/   50] | d_loss: 0.4243 | g_loss: 0.2015
# Epoch [   20/   50] | d_loss: 0.4331 | g_loss: 0.2053
# Epoch [   20/   50] | d_loss: 0.4213 | g_loss: 0.1954
# Epoch [   20/   50] | d_loss: 0.4344 | g_loss: 0.2051
# Epoch [   20/   50] | d_loss: 0.4255 | g_loss: 0.2237
# Epoch [   20/   50] | d_loss: 0.3956 | g_loss: 0.2010
# Epoch [   20/   50] | d_loss: 0.4284 | g_loss: 0.2350
# Epoch [   20/   50] | d_loss: 0.4186 | g_loss: 0.2007
# Epoch [   20/   50] | d_loss: 0.4397 | g_loss: 0.2164
# Epoch [   20/   50] | d_loss: 0.4178 | g_loss: 0.2160
# Epoch [   20/   50] | d_loss: 0.4023 | g_loss: 0.2187
# Epoch [   20/   50] | d_loss: 0.4185 | g_loss: 0.2366
# Epoch [   20/   50] | d_loss: 0.4469 | g_loss: 0.1997
# Epoch [   21/   50] | d_loss: 0.4290 | g_loss: 0.2361
# Epoch [   21/   50] | d_loss: 0.4141 | g_loss: 0.2005
# Epoch [   21/   50] | d_loss: 0.3794 | g_loss: 0.2588
# Epoch [   21/   50] | d_loss: 0.4118 | g_loss: 0.2176
# Epoch [   21/   50] | d_loss: 0.4220 | g_loss: 0.2019
# Epoch [   21/   50] | d_loss: 0.4186 | g_loss: 0.2193
# Epoch [   21/   50] | d_loss: 0.4426 | g_loss: 0.1942
# Epoch [   21/   50] | d_loss: 0.4089 | g_loss: 0.2143
# Epoch [   21/   50] | d_loss: 0.4080 | g_loss: 0.2288
# Epoch [   21/   50] | d_loss: 0.4023 | g_loss: 0.2523
# Epoch [   21/   50] | d_loss: 0.4290 | g_loss: 0.1903
# Epoch [   21/   50] | d_loss: 0.4205 | g_loss: 0.2441
# Epoch [   21/   50] | d_loss: 0.4365 | g_loss: 0.1978
# Epoch [   21/   50] | d_loss: 0.4103 | g_loss: 0.2223
# Epoch [   21/   50] | d_loss: 0.4427 | g_loss: 0.1937
# Epoch [   22/   50] | d_loss: 0.4612 | g_loss: 0.2063
# Epoch [   22/   50] | d_loss: 0.4265 | g_loss: 0.2257
# Epoch [   22/   50] | d_loss: 0.4111 | g_loss: 0.2506
# Epoch [   22/   50] | d_loss: 0.3934 | g_loss: 0.2325
# Epoch [   22/   50] | d_loss: 0.4028 | g_loss: 0.2410
# Epoch [   22/   50] | d_loss: 0.4049 | g_loss: 0.2248
# Epoch [   22/   50] | d_loss: 0.3748 | g_loss: 0.2426
# Epoch [   22/   50] | d_loss: 0.4039 | g_loss: 0.2167
# Epoch [   22/   50] | d_loss: 0.4052 | g_loss: 0.2282
# Epoch [   22/   50] | d_loss: 0.4339 | g_loss: 0.2119
# Epoch [   22/   50] | d_loss: 0.4270 | g_loss: 0.2000
# Epoch [   22/   50] | d_loss: 0.4140 | g_loss: 0.2328
# Epoch [   22/   50] | d_loss: 0.4121 | g_loss: 0.2140
# Epoch [   22/   50] | d_loss: 0.4101 | g_loss: 0.2277
# Epoch [   22/   50] | d_loss: 0.4041 | g_loss: 0.2346
# Epoch [   23/   50] | d_loss: 0.4225 | g_loss: 0.2012
# Epoch [   23/   50] | d_loss: 0.4597 | g_loss: 0.2047
# Epoch [   23/   50] | d_loss: 0.4066 | g_loss: 0.2158
# Epoch [   23/   50] | d_loss: 0.4266 | g_loss: 0.2148
# Epoch [   23/   50] | d_loss: 0.3877 | g_loss: 0.2635
# Epoch [   23/   50] | d_loss: 0.4152 | g_loss: 0.2407
# Epoch [   23/   50] | d_loss: 0.4169 | g_loss: 0.2305
# Epoch [   23/   50] | d_loss: 0.4111 | g_loss: 0.2072
# Epoch [   23/   50] | d_loss: 0.4106 | g_loss: 0.2065
# Epoch [   23/   50] | d_loss: 0.4057 | g_loss: 0.2229
# Epoch [   23/   50] | d_loss: 0.4246 | g_loss: 0.2010
# Epoch [   23/   50] | d_loss: 0.4095 | g_loss: 0.2321
# Epoch [   23/   50] | d_loss: 0.4363 | g_loss: 0.2043
# Epoch [   23/   50] | d_loss: 0.4051 | g_loss: 0.2406
# Epoch [   23/   50] | d_loss: 0.4204 | g_loss: 0.2202
# Epoch [   24/   50] | d_loss: 0.3998 | g_loss: 0.2238
# Epoch [   24/   50] | d_loss: 0.3812 | g_loss: 0.2439
# Epoch [   24/   50] | d_loss: 0.4323 | g_loss: 0.2586
# Epoch [   24/   50] | d_loss: 0.3934 | g_loss: 0.2456
# Epoch [   24/   50] | d_loss: 0.3978 | g_loss: 0.2316
# Epoch [   24/   50] | d_loss: 0.4270 | g_loss: 0.2522
# Epoch [   24/   50] | d_loss: 0.4050 | g_loss: 0.2716
# Epoch [   24/   50] | d_loss: 0.4020 | g_loss: 0.2070
# Epoch [   24/   50] | d_loss: 0.3955 | g_loss: 0.2212
# Epoch [   24/   50] | d_loss: 0.4268 | g_loss: 0.2111
# Epoch [   24/   50] | d_loss: 0.4400 | g_loss: 0.2729
# Epoch [   24/   50] | d_loss: 0.4324 | g_loss: 0.2269
# Epoch [   24/   50] | d_loss: 0.3847 | g_loss: 0.2469
# Epoch [   24/   50] | d_loss: 0.4320 | g_loss: 0.1951
# Epoch [   24/   50] | d_loss: 0.3869 | g_loss: 0.2629
# Epoch [   25/   50] | d_loss: 0.4029 | g_loss: 0.2688
# Epoch [   25/   50] | d_loss: 0.3807 | g_loss: 0.2502
# Epoch [   25/   50] | d_loss: 0.4097 | g_loss: 0.2437
# Epoch [   25/   50] | d_loss: 0.4274 | g_loss: 0.2318
# Epoch [   25/   50] | d_loss: 0.4210 | g_loss: 0.2305
# Epoch [   25/   50] | d_loss: 0.4116 | g_loss: 0.2815
# Epoch [   25/   50] | d_loss: 0.4122 | g_loss: 0.2563
# Epoch [   25/   50] | d_loss: 0.3858 | g_loss: 0.2456
# Epoch [   25/   50] | d_loss: 0.4080 | g_loss: 0.2259
# Epoch [   25/   50] | d_loss: 0.3889 | g_loss: 0.2256
# Epoch [   25/   50] | d_loss: 0.4026 | g_loss: 0.2109
# Epoch [   25/   50] | d_loss: 0.4090 | g_loss: 0.2579
# Epoch [   25/   50] | d_loss: 0.3878 | g_loss: 0.2101
# Epoch [   25/   50] | d_loss: 0.4206 | g_loss: 0.2335
# Epoch [   25/   50] | d_loss: 0.3931 | g_loss: 0.2509
# Epoch [   26/   50] | d_loss: 0.4034 | g_loss: 0.1825
# Epoch [   26/   50] | d_loss: 0.4051 | g_loss: 0.2541
# Epoch [   26/   50] | d_loss: 0.4011 | g_loss: 0.2729
# Epoch [   26/   50] | d_loss: 0.4169 | g_loss: 0.4573
# Epoch [   26/   50] | d_loss: 0.3811 | g_loss: 0.2179
# Epoch [   26/   50] | d_loss: 0.3861 | g_loss: 0.3445
# Epoch [   26/   50] | d_loss: 0.4018 | g_loss: 0.2075
# Epoch [   26/   50] | d_loss: 0.3940 | g_loss: 0.2382
# Epoch [   26/   50] | d_loss: 0.3932 | g_loss: 0.2188
# Epoch [   26/   50] | d_loss: 0.4435 | g_loss: 0.2508
# Epoch [   26/   50] | d_loss: 0.4181 | g_loss: 0.2765
# Epoch [   26/   50] | d_loss: 0.4008 | g_loss: 0.2994
# Epoch [   26/   50] | d_loss: 0.4471 | g_loss: 0.2021
# Epoch [   26/   50] | d_loss: 0.3958 | g_loss: 0.3027
# Epoch [   26/   50] | d_loss: 0.3671 | g_loss: 0.2594
# Epoch [   27/   50] | d_loss: 0.3537 | g_loss: 0.2783
# Epoch [   27/   50] | d_loss: 0.3858 | g_loss: 0.2556
# Epoch [   27/   50] | d_loss: 0.3876 | g_loss: 0.2494
# Epoch [   27/   50] | d_loss: 0.4804 | g_loss: 0.0885
# Epoch [   27/   50] | d_loss: 0.4463 | g_loss: 0.2720
# Epoch [   27/   50] | d_loss: 0.3632 | g_loss: 0.2672
# Epoch [   27/   50] | d_loss: 0.3891 | g_loss: 0.2753
# Epoch [   27/   50] | d_loss: 0.3697 | g_loss: 0.2819
# Epoch [   27/   50] | d_loss: 0.4263 | g_loss: 0.2991
# Epoch [   27/   50] | d_loss: 0.3261 | g_loss: 0.4258
# Epoch [   27/   50] | d_loss: 0.4265 | g_loss: 0.2091
# Epoch [   27/   50] | d_loss: 0.3061 | g_loss: 0.3280
# Epoch [   27/   50] | d_loss: 0.3201 | g_loss: 0.4629
# Epoch [   27/   50] | d_loss: 0.3187 | g_loss: 0.3207
# Epoch [   27/   50] | d_loss: 0.3368 | g_loss: 0.4357
# Epoch [   28/   50] | d_loss: 0.4455 | g_loss: 0.2767
# Epoch [   28/   50] | d_loss: 0.3213 | g_loss: 0.3610
# Epoch [   28/   50] | d_loss: 0.2671 | g_loss: 0.5273
# Epoch [   28/   50] | d_loss: 0.3181 | g_loss: 0.4868
# Epoch [   28/   50] | d_loss: 0.2775 | g_loss: 0.2332
# Epoch [   28/   50] | d_loss: 0.3091 | g_loss: 0.4517
# Epoch [   28/   50] | d_loss: 0.4344 | g_loss: 0.2286
# Epoch [   28/   50] | d_loss: 0.2817 | g_loss: 0.2284
# Epoch [   28/   50] | d_loss: 0.3493 | g_loss: 0.2865
# Epoch [   28/   50] | d_loss: 0.2383 | g_loss: 0.4241
# Epoch [   28/   50] | d_loss: 0.2418 | g_loss: 0.3147
# Epoch [   28/   50] | d_loss: 0.3112 | g_loss: 0.3107
# Epoch [   28/   50] | d_loss: 0.2201 | g_loss: 0.8478
# Epoch [   28/   50] | d_loss: 0.3062 | g_loss: 0.5347
# Epoch [   28/   50] | d_loss: 0.2850 | g_loss: 0.4386
# Epoch [   29/   50] | d_loss: 0.2694 | g_loss: 0.1608
# Epoch [   29/   50] | d_loss: 0.2671 | g_loss: 0.3679
# Epoch [   29/   50] | d_loss: 0.3000 | g_loss: 0.2772
# Epoch [   29/   50] | d_loss: 0.3702 | g_loss: 0.4599
# Epoch [   29/   50] | d_loss: 0.2816 | g_loss: 0.4417
# Epoch [   29/   50] | d_loss: 0.2713 | g_loss: 0.3257
# Epoch [   29/   50] | d_loss: 0.2399 | g_loss: 0.4400
# Epoch [   29/   50] | d_loss: 0.2573 | g_loss: 0.2621
# Epoch [   29/   50] | d_loss: 0.2228 | g_loss: 0.4751
# Epoch [   29/   50] | d_loss: 0.2776 | g_loss: 0.5736
# Epoch [   29/   50] | d_loss: 0.2889 | g_loss: 0.1414
# Epoch [   29/   50] | d_loss: 0.2790 | g_loss: 0.3433
# Epoch [   29/   50] | d_loss: 0.2046 | g_loss: 0.5870
# Epoch [   29/   50] | d_loss: 0.2204 | g_loss: 0.3189
# Epoch [   29/   50] | d_loss: 0.2317 | g_loss: 0.2754
# Epoch [   30/   50] | d_loss: 0.2912 | g_loss: 0.5528
# Epoch [   30/   50] | d_loss: 0.3437 | g_loss: 0.1332
# Epoch [   30/   50] | d_loss: 0.2199 | g_loss: 0.4461
# Epoch [   30/   50] | d_loss: 0.1759 | g_loss: 0.4080
# Epoch [   30/   50] | d_loss: 0.2051 | g_loss: 0.3953
# Epoch [   30/   50] | d_loss: 0.3590 | g_loss: 0.2250
# Epoch [   30/   50] | d_loss: 0.2948 | g_loss: 0.1830
# Epoch [   30/   50] | d_loss: 0.3153 | g_loss: 0.5174
# Epoch [   30/   50] | d_loss: 0.2082 | g_loss: 0.6027
# Epoch [   30/   50] | d_loss: 0.1793 | g_loss: 0.6353
# Epoch [   30/   50] | d_loss: 0.2083 | g_loss: 0.2329
# Epoch [   30/   50] | d_loss: 0.1227 | g_loss: 0.5211
# Epoch [   30/   50] | d_loss: 0.2173 | g_loss: 0.3609
# Epoch [   30/   50] | d_loss: 0.1884 | g_loss: 0.4322
# Epoch [   30/   50] | d_loss: 0.2299 | g_loss: 0.4935
# Epoch [   31/   50] | d_loss: 0.2206 | g_loss: 0.7207
# Epoch [   31/   50] | d_loss: 0.1948 | g_loss: 0.3657
# Epoch [   31/   50] | d_loss: 0.2092 | g_loss: 0.3457
# Epoch [   31/   50] | d_loss: 0.1844 | g_loss: 0.4428
# Epoch [   31/   50] | d_loss: 0.2047 | g_loss: 0.5747
# Epoch [   31/   50] | d_loss: 0.1504 | g_loss: 0.4220
# Epoch [   31/   50] | d_loss: 0.1634 | g_loss: 0.6044
# Epoch [   31/   50] | d_loss: 0.2067 | g_loss: 0.3321
# Epoch [   31/   50] | d_loss: 0.1769 | g_loss: 0.4327
# Epoch [   31/   50] | d_loss: 0.1341 | g_loss: 0.6612
# Epoch [   31/   50] | d_loss: 0.2558 | g_loss: 0.1528
# Epoch [   31/   50] | d_loss: 0.2280 | g_loss: 0.4070
# Epoch [   31/   50] | d_loss: 0.2632 | g_loss: 0.3345
# Epoch [   31/   50] | d_loss: 0.1905 | g_loss: 0.5052
# Epoch [   31/   50] | d_loss: 0.2376 | g_loss: 0.5023
# Epoch [   32/   50] | d_loss: 0.2269 | g_loss: 0.6189
# Epoch [   32/   50] | d_loss: 0.1787 | g_loss: 0.3556
# Epoch [   32/   50] | d_loss: 0.1937 | g_loss: 0.5078
# Epoch [   32/   50] | d_loss: 0.2424 | g_loss: 0.4460
# Epoch [   32/   50] | d_loss: 0.1760 | g_loss: 0.3625
# Epoch [   32/   50] | d_loss: 0.2278 | g_loss: 0.4818
# Epoch [   32/   50] | d_loss: 0.2104 | g_loss: 0.3323
# Epoch [   32/   50] | d_loss: 0.2115 | g_loss: 0.5063
# Epoch [   32/   50] | d_loss: 0.1515 | g_loss: 0.6734
# Epoch [   32/   50] | d_loss: 0.1901 | g_loss: 0.4684
# Epoch [   32/   50] | d_loss: 0.2802 | g_loss: 0.2762
# Epoch [   32/   50] | d_loss: 0.2191 | g_loss: 0.4256
# Epoch [   32/   50] | d_loss: 0.1360 | g_loss: 0.4301
# Epoch [   32/   50] | d_loss: 0.4147 | g_loss: 0.1964
# Epoch [   32/   50] | d_loss: 0.4014 | g_loss: 0.2242
# Epoch [   33/   50] | d_loss: 0.4446 | g_loss: 0.2231
# Epoch [   33/   50] | d_loss: 0.4169 | g_loss: 0.2359
# Epoch [   33/   50] | d_loss: 0.4090 | g_loss: 0.2162
# Epoch [   33/   50] | d_loss: 0.3892 | g_loss: 0.2086
# Epoch [   33/   50] | d_loss: 0.3331 | g_loss: 0.4542
# Epoch [   33/   50] | d_loss: 0.1674 | g_loss: 0.4957
# Epoch [   33/   50] | d_loss: 0.2143 | g_loss: 0.4097
# Epoch [   33/   50] | d_loss: 0.2461 | g_loss: 0.6712
# Epoch [   33/   50] | d_loss: 0.3506 | g_loss: 0.2671
# Epoch [   33/   50] | d_loss: 0.2520 | g_loss: 0.3510
# Epoch [   33/   50] | d_loss: 0.1786 | g_loss: 0.6694
# Epoch [   33/   50] | d_loss: 0.2203 | g_loss: 0.7178
# Epoch [   33/   50] | d_loss: 0.1630 | g_loss: 0.5591
# Epoch [   33/   50] | d_loss: 0.2201 | g_loss: 0.6384
# Epoch [   33/   50] | d_loss: 0.1786 | g_loss: 0.4602
# Epoch [   34/   50] | d_loss: 0.1474 | g_loss: 0.4095
# Epoch [   34/   50] | d_loss: 0.5062 | g_loss: 0.8648
# Epoch [   34/   50] | d_loss: 0.1562 | g_loss: 0.3447
# Epoch [   34/   50] | d_loss: 0.2336 | g_loss: 0.2423
# Epoch [   34/   50] | d_loss: 0.1719 | g_loss: 0.6610
# Epoch [   34/   50] | d_loss: 0.1931 | g_loss: 0.4589
# Epoch [   34/   50] | d_loss: 0.1622 | g_loss: 0.3767
# Epoch [   34/   50] | d_loss: 0.2064 | g_loss: 0.7692
# Epoch [   34/   50] | d_loss: 0.1653 | g_loss: 0.5173
# Epoch [   34/   50] | d_loss: 0.1452 | g_loss: 0.6394
# Epoch [   34/   50] | d_loss: 0.1637 | g_loss: 0.5100
# Epoch [   34/   50] | d_loss: 0.1849 | g_loss: 1.0767
# Epoch [   34/   50] | d_loss: 0.1345 | g_loss: 0.4699
# Epoch [   34/   50] | d_loss: 0.2035 | g_loss: 0.3978
# Epoch [   34/   50] | d_loss: 0.1208 | g_loss: 0.6121
# Epoch [   35/   50] | d_loss: 0.2248 | g_loss: 0.7988
# Epoch [   35/   50] | d_loss: 0.1807 | g_loss: 0.7011
# Epoch [   35/   50] | d_loss: 0.1197 | g_loss: 0.4285
# Epoch [   35/   50] | d_loss: 0.1435 | g_loss: 0.6431
# Epoch [   35/   50] | d_loss: 0.7896 | g_loss: 0.3918
# Epoch [   35/   50] | d_loss: 0.1172 | g_loss: 0.5313
# Epoch [   35/   50] | d_loss: 0.1981 | g_loss: 0.5040
# Epoch [   35/   50] | d_loss: 0.1323 | g_loss: 0.5634
# Epoch [   35/   50] | d_loss: 0.1622 | g_loss: 0.4987
# Epoch [   35/   50] | d_loss: 0.1288 | g_loss: 0.4745
# Epoch [   35/   50] | d_loss: 0.2179 | g_loss: 0.9496
# Epoch [   35/   50] | d_loss: 0.1568 | g_loss: 0.4551
# Epoch [   35/   50] | d_loss: 0.0902 | g_loss: 0.7854
# Epoch [   35/   50] | d_loss: 0.1807 | g_loss: 0.6777
# Epoch [   35/   50] | d_loss: 0.1303 | g_loss: 0.4568
# Epoch [   36/   50] | d_loss: 0.1738 | g_loss: 0.3198
# Epoch [   36/   50] | d_loss: 0.1118 | g_loss: 0.6561
# Epoch [   36/   50] | d_loss: 0.1230 | g_loss: 0.6952
# Epoch [   36/   50] | d_loss: 0.1438 | g_loss: 0.3590
# Epoch [   36/   50] | d_loss: 0.4034 | g_loss: 0.2623
# Epoch [   36/   50] | d_loss: 0.2095 | g_loss: 0.5254
# Epoch [   36/   50] | d_loss: 0.2143 | g_loss: 0.6442
# Epoch [   36/   50] | d_loss: 0.1319 | g_loss: 0.4771
# Epoch [   36/   50] | d_loss: 0.2209 | g_loss: 0.5679
# Epoch [   36/   50] | d_loss: 0.1663 | g_loss: 0.4710
# Epoch [   36/   50] | d_loss: 0.1310 | g_loss: 0.3872
# Epoch [   36/   50] | d_loss: 0.1501 | g_loss: 0.4623
# Epoch [   36/   50] | d_loss: 0.1789 | g_loss: 0.4513
# Epoch [   36/   50] | d_loss: 0.2834 | g_loss: 0.9296
# Epoch [   36/   50] | d_loss: 0.1550 | g_loss: 0.5698
# Epoch [   37/   50] | d_loss: 0.1350 | g_loss: 0.4888
# Epoch [   37/   50] | d_loss: 0.1548 | g_loss: 0.7990
# Epoch [   37/   50] | d_loss: 0.1251 | g_loss: 0.5348
# Epoch [   37/   50] | d_loss: 0.3314 | g_loss: 0.6001
# Epoch [   37/   50] | d_loss: 0.1692 | g_loss: 0.8251
# Epoch [   37/   50] | d_loss: 0.1373 | g_loss: 0.5095
# Epoch [   37/   50] | d_loss: 0.1989 | g_loss: 0.3165
# Epoch [   37/   50] | d_loss: 0.1933 | g_loss: 0.4022
# Epoch [   37/   50] | d_loss: 0.1213 | g_loss: 0.5163
# Epoch [   37/   50] | d_loss: 0.1538 | g_loss: 0.4330
# Epoch [   37/   50] | d_loss: 0.1623 | g_loss: 0.3447
# Epoch [   37/   50] | d_loss: 0.1616 | g_loss: 1.0202
# Epoch [   37/   50] | d_loss: 0.6420 | g_loss: 0.6824
# Epoch [   37/   50] | d_loss: 0.1026 | g_loss: 0.5714
# Epoch [   37/   50] | d_loss: 0.1799 | g_loss: 0.9291
# Epoch [   38/   50] | d_loss: 0.2216 | g_loss: 0.1858
# Epoch [   38/   50] | d_loss: 0.1351 | g_loss: 0.6176
# Epoch [   38/   50] | d_loss: 0.1387 | g_loss: 0.6670
# Epoch [   38/   50] | d_loss: 0.1977 | g_loss: 0.3420
# Epoch [   38/   50] | d_loss: 0.1117 | g_loss: 0.6082
# Epoch [   38/   50] | d_loss: 0.1103 | g_loss: 0.7588
# Epoch [   38/   50] | d_loss: 0.1298 | g_loss: 0.8328
# Epoch [   38/   50] | d_loss: 0.1808 | g_loss: 0.3246
# Epoch [   38/   50] | d_loss: 0.1292 | g_loss: 0.5606
# Epoch [   38/   50] | d_loss: 0.1449 | g_loss: 0.7727
# Epoch [   38/   50] | d_loss: 0.1003 | g_loss: 0.7482
# Epoch [   38/   50] | d_loss: 0.1422 | g_loss: 0.5328
# Epoch [   38/   50] | d_loss: 0.1670 | g_loss: 0.6172
# Epoch [   38/   50] | d_loss: 0.1527 | g_loss: 0.7804
# Epoch [   38/   50] | d_loss: 0.1244 | g_loss: 0.5282
# Epoch [   39/   50] | d_loss: 0.1305 | g_loss: 0.5754
# Epoch [   39/   50] | d_loss: 0.0937 | g_loss: 0.6969
# Epoch [   39/   50] | d_loss: 0.0985 | g_loss: 0.6344
# Epoch [   39/   50] | d_loss: 0.1592 | g_loss: 0.7133
# Epoch [   39/   50] | d_loss: 0.1486 | g_loss: 0.3936
# Epoch [   39/   50] | d_loss: 0.1698 | g_loss: 0.3503
# Epoch [   39/   50] | d_loss: 0.1263 | g_loss: 0.4090
# Epoch [   39/   50] | d_loss: 0.4793 | g_loss: 0.2679
# Epoch [   39/   50] | d_loss: 0.1763 | g_loss: 0.5754
# Epoch [   39/   50] | d_loss: 0.2625 | g_loss: 0.4674
# Epoch [   39/   50] | d_loss: 0.1549 | g_loss: 0.4865
# Epoch [   39/   50] | d_loss: 0.1429 | g_loss: 0.5446
# Epoch [   39/   50] | d_loss: 0.1062 | g_loss: 0.5794
# Epoch [   39/   50] | d_loss: 0.1941 | g_loss: 0.3044
# Epoch [   39/   50] | d_loss: 0.0789 | g_loss: 0.9954
# Epoch [   40/   50] | d_loss: 0.1977 | g_loss: 0.8932
# Epoch [   40/   50] | d_loss: 0.1443 | g_loss: 0.4217
# Epoch [   40/   50] | d_loss: 0.1919 | g_loss: 0.2895
# Epoch [   40/   50] | d_loss: 0.5495 | g_loss: 0.0484
# Epoch [   40/   50] | d_loss: 0.1547 | g_loss: 0.3966
# Epoch [   40/   50] | d_loss: 0.1450 | g_loss: 0.6276
# Epoch [   40/   50] | d_loss: 0.1184 | g_loss: 0.5408
# Epoch [   40/   50] | d_loss: 0.1813 | g_loss: 0.9191
# Epoch [   40/   50] | d_loss: 0.1280 | g_loss: 0.5094
# Epoch [   40/   50] | d_loss: 0.1679 | g_loss: 0.3923
# Epoch [   40/   50] | d_loss: 0.2267 | g_loss: 0.2885
# Epoch [   40/   50] | d_loss: 0.1239 | g_loss: 0.7319
# Epoch [   40/   50] | d_loss: 0.1615 | g_loss: 0.5419
# Epoch [   40/   50] | d_loss: 0.1239 | g_loss: 0.8075
# Epoch [   40/   50] | d_loss: 0.4586 | g_loss: 0.2829
# Epoch [   41/   50] | d_loss: 0.4754 | g_loss: 0.2129
# Epoch [   41/   50] | d_loss: 0.4024 | g_loss: 0.2951
# Epoch [   41/   50] | d_loss: 0.1308 | g_loss: 0.5005
# Epoch [   41/   50] | d_loss: 0.1640 | g_loss: 0.3742
# Epoch [   41/   50] | d_loss: 0.1578 | g_loss: 0.5198
# Epoch [   41/   50] | d_loss: 0.1754 | g_loss: 0.6751
# Epoch [   41/   50] | d_loss: 0.1376 | g_loss: 0.4729
# Epoch [   41/   50] | d_loss: 0.3378 | g_loss: 0.1152
# Epoch [   41/   50] | d_loss: 0.1808 | g_loss: 0.3275
# Epoch [   41/   50] | d_loss: 0.1552 | g_loss: 0.7017
# Epoch [   41/   50] | d_loss: 0.1423 | g_loss: 0.5479
# Epoch [   41/   50] | d_loss: 0.0585 | g_loss: 0.5931
# Epoch [   41/   50] | d_loss: 0.1434 | g_loss: 0.4944
# Epoch [   41/   50] | d_loss: 0.1632 | g_loss: 0.7316
# Epoch [   41/   50] | d_loss: 0.1140 | g_loss: 0.4671
# Epoch [   42/   50] | d_loss: 0.1581 | g_loss: 0.8912
# Epoch [   42/   50] | d_loss: 0.1920 | g_loss: 0.6025
# Epoch [   42/   50] | d_loss: 0.1325 | g_loss: 0.4622
# Epoch [   42/   50] | d_loss: 0.1133 | g_loss: 0.5636
# Epoch [   42/   50] | d_loss: 0.1210 | g_loss: 0.4914
# Epoch [   42/   50] | d_loss: 0.1881 | g_loss: 0.8120
# Epoch [   42/   50] | d_loss: 0.1792 | g_loss: 0.5738
# Epoch [   42/   50] | d_loss: 0.0656 | g_loss: 0.6800
# Epoch [   42/   50] | d_loss: 0.3443 | g_loss: 0.1977
# Epoch [   42/   50] | d_loss: 0.1809 | g_loss: 0.4042
# Epoch [   42/   50] | d_loss: 0.2068 | g_loss: 0.3931
# Epoch [   42/   50] | d_loss: 0.0826 | g_loss: 0.4231
# Epoch [   42/   50] | d_loss: 0.1573 | g_loss: 0.2610
# Epoch [   42/   50] | d_loss: 0.1319 | g_loss: 0.5107
# Epoch [   42/   50] | d_loss: 0.4505 | g_loss: 0.2432
# Epoch [   43/   50] | d_loss: 0.4134 | g_loss: 0.1591
# Epoch [   43/   50] | d_loss: 0.1515 | g_loss: 0.5121
# Epoch [   43/   50] | d_loss: 0.1893 | g_loss: 0.3996
# Epoch [   43/   50] | d_loss: 0.1145 | g_loss: 0.5651
# Epoch [   43/   50] | d_loss: 0.1191 | g_loss: 0.7873
# Epoch [   43/   50] | d_loss: 0.0849 | g_loss: 0.7429
# Epoch [   43/   50] | d_loss: 0.1295 | g_loss: 0.7154
# Epoch [   43/   50] | d_loss: 0.1827 | g_loss: 0.7018
# Epoch [   43/   50] | d_loss: 0.1288 | g_loss: 0.5769
# Epoch [   43/   50] | d_loss: 0.1457 | g_loss: 0.4330
# Epoch [   43/   50] | d_loss: 0.1147 | g_loss: 0.5942
# Epoch [   43/   50] | d_loss: 0.1050 | g_loss: 0.7987
# Epoch [   43/   50] | d_loss: 0.1177 | g_loss: 0.8173
# Epoch [   43/   50] | d_loss: 0.1001 | g_loss: 0.8340
# Epoch [   43/   50] | d_loss: 0.1029 | g_loss: 0.5061
# Epoch [   44/   50] | d_loss: 0.1175 | g_loss: 0.4715
# Epoch [   44/   50] | d_loss: 0.0887 | g_loss: 0.5695
# Epoch [   44/   50] | d_loss: 0.1422 | g_loss: 0.5650
# Epoch [   44/   50] | d_loss: 0.2000 | g_loss: 0.7348
# Epoch [   44/   50] | d_loss: 0.2029 | g_loss: 0.6857
# Epoch [   44/   50] | d_loss: 0.1551 | g_loss: 0.6020
# Epoch [   44/   50] | d_loss: 0.0755 | g_loss: 0.5747
# Epoch [   44/   50] | d_loss: 0.1206 | g_loss: 0.3905
# Epoch [   44/   50] | d_loss: 0.0796 | g_loss: 0.7250
# Epoch [   44/   50] | d_loss: 0.5683 | g_loss: 0.1296
# Epoch [   44/   50] | d_loss: 0.4383 | g_loss: 0.2060
# Epoch [   44/   50] | d_loss: 0.4718 | g_loss: 0.2721
# Epoch [   44/   50] | d_loss: 0.3921 | g_loss: 0.2328
# Epoch [   44/   50] | d_loss: 0.3418 | g_loss: 0.3114
# Epoch [   44/   50] | d_loss: 0.1488 | g_loss: 0.4653
# Epoch [   45/   50] | d_loss: 0.1267 | g_loss: 0.6081
# Epoch [   45/   50] | d_loss: 0.1638 | g_loss: 0.3092
# Epoch [   45/   50] | d_loss: 0.1806 | g_loss: 0.5973
# Epoch [   45/   50] | d_loss: 0.1259 | g_loss: 0.7190
# Epoch [   45/   50] | d_loss: 0.2034 | g_loss: 0.9413
# Epoch [   45/   50] | d_loss: 0.1516 | g_loss: 0.4137
# Epoch [   45/   50] | d_loss: 0.0869 | g_loss: 0.5862
# Epoch [   45/   50] | d_loss: 0.1196 | g_loss: 0.6115
# Epoch [   45/   50] | d_loss: 0.1203 | g_loss: 0.5609
# Epoch [   45/   50] | d_loss: 0.2624 | g_loss: 0.5169
# Epoch [   45/   50] | d_loss: 0.2353 | g_loss: 0.4104
# Epoch [   45/   50] | d_loss: 0.0929 | g_loss: 0.5582
# Epoch [   45/   50] | d_loss: 0.1158 | g_loss: 0.4702
# Epoch [   45/   50] | d_loss: 0.1172 | g_loss: 0.5026
# Epoch [   45/   50] | d_loss: 0.2071 | g_loss: 0.9252
# Epoch [   46/   50] | d_loss: 0.1359 | g_loss: 0.9979
# Epoch [   46/   50] | d_loss: 0.2859 | g_loss: 0.0324
# Epoch [   46/   50] | d_loss: 0.1892 | g_loss: 0.3121
# Epoch [   46/   50] | d_loss: 0.2138 | g_loss: 0.9619
# Epoch [   46/   50] | d_loss: 0.1160 | g_loss: 0.6129
# Epoch [   46/   50] | d_loss: 0.1257 | g_loss: 0.6119
# Epoch [   46/   50] | d_loss: 0.1367 | g_loss: 0.4703
# Epoch [   46/   50] | d_loss: 0.1086 | g_loss: 0.5700
# Epoch [   46/   50] | d_loss: 0.1230 | g_loss: 0.4263
# Epoch [   46/   50] | d_loss: 0.1673 | g_loss: 0.3146
# Epoch [   46/   50] | d_loss: 0.1588 | g_loss: 0.4477
# Epoch [   46/   50] | d_loss: 0.1080 | g_loss: 0.8759
# Epoch [   46/   50] | d_loss: 0.0905 | g_loss: 0.5884
# Epoch [   46/   50] | d_loss: 0.1119 | g_loss: 0.5372
# Epoch [   46/   50] | d_loss: 0.6056 | g_loss: 0.0887
# Epoch [   47/   50] | d_loss: 0.5026 | g_loss: 0.1501
# Epoch [   47/   50] | d_loss: 0.4012 | g_loss: 0.2679
# Epoch [   47/   50] | d_loss: 0.1398 | g_loss: 0.9026
# Epoch [   47/   50] | d_loss: 0.2162 | g_loss: 0.3800
# Epoch [   47/   50] | d_loss: 0.1609 | g_loss: 0.7857
# Epoch [   47/   50] | d_loss: 0.0762 | g_loss: 0.6160
# Epoch [   47/   50] | d_loss: 0.1689 | g_loss: 0.6714
# Epoch [   47/   50] | d_loss: 0.0742 | g_loss: 0.6622
# Epoch [   47/   50] | d_loss: 0.1195 | g_loss: 0.6431
# Epoch [   47/   50] | d_loss: 0.1889 | g_loss: 0.6595
# Epoch [   47/   50] | d_loss: 0.1416 | g_loss: 0.8708
# Epoch [   47/   50] | d_loss: 0.1311 | g_loss: 0.4977
# Epoch [   47/   50] | d_loss: 0.0696 | g_loss: 0.8470
# Epoch [   47/   50] | d_loss: 0.1070 | g_loss: 0.6862
# Epoch [   47/   50] | d_loss: 0.0930 | g_loss: 0.5636
# Epoch [   48/   50] | d_loss: 0.1569 | g_loss: 1.0156
# Epoch [   48/   50] | d_loss: 0.1536 | g_loss: 0.6010
# Epoch [   48/   50] | d_loss: 0.0940 | g_loss: 0.6818
# Epoch [   48/   50] | d_loss: 0.1154 | g_loss: 0.5359
# Epoch [   48/   50] | d_loss: 0.0959 | g_loss: 0.4688
# Epoch [   48/   50] | d_loss: 0.1767 | g_loss: 0.4166
# Epoch [   48/   50] | d_loss: 0.1343 | g_loss: 0.5245
# Epoch [   48/   50] | d_loss: 0.1415 | g_loss: 0.5326
# Epoch [   48/   50] | d_loss: 0.1770 | g_loss: 0.2787
# Epoch [   48/   50] | d_loss: 0.0692 | g_loss: 0.8480
# Epoch [   48/   50] | d_loss: 0.1766 | g_loss: 0.6102
# Epoch [   48/   50] | d_loss: 0.0812 | g_loss: 0.7075
# Epoch [   48/   50] | d_loss: 0.1233 | g_loss: 0.4430
# Epoch [   48/   50] | d_loss: 0.1517 | g_loss: 0.6521
# Epoch [   48/   50] | d_loss: 0.0971 | g_loss: 0.4616
# Epoch [   49/   50] | d_loss: 0.0876 | g_loss: 0.5269
# Epoch [   49/   50] | d_loss: 0.1177 | g_loss: 0.6106
# Epoch [   49/   50] | d_loss: 0.0853 | g_loss: 0.7848
# Epoch [   49/   50] | d_loss: 0.0685 | g_loss: 0.7395
# Epoch [   49/   50] | d_loss: 0.1180 | g_loss: 0.8432
# Epoch [   49/   50] | d_loss: 0.1061 | g_loss: 0.6507
# Epoch [   49/   50] | d_loss: 0.4116 | g_loss: 0.2702
# Epoch [   49/   50] | d_loss: 0.2291 | g_loss: 0.9959
# Epoch [   49/   50] | d_loss: 0.1396 | g_loss: 0.4667
# Epoch [   49/   50] | d_loss: 0.1430 | g_loss: 0.6045
# Epoch [   49/   50] | d_loss: 0.1826 | g_loss: 0.7387
# Epoch [   49/   50] | d_loss: 0.1623 | g_loss: 0.7119
# Epoch [   49/   50] | d_loss: 0.1681 | g_loss: 0.4429
# Epoch [   49/   50] | d_loss: 0.1807 | g_loss: 0.4610
# Epoch [   49/   50] | d_loss: 0.0813 | g_loss: 0.7282
# Epoch [   50/   50] | d_loss: 0.1896 | g_loss: 0.8439
# Epoch [   50/   50] | d_loss: 0.1154 | g_loss: 0.7549
# Epoch [   50/   50] | d_loss: 0.1333 | g_loss: 0.8994
# Epoch [   50/   50] | d_loss: 0.1101 | g_loss: 0.7629
# Epoch [   50/   50] | d_loss: 0.1165 | g_loss: 0.9014
# Epoch [   50/   50] | d_loss: 0.1234 | g_loss: 0.6791
# Epoch [   50/   50] | d_loss: 0.1277 | g_loss: 0.5113
# Epoch [   50/   50] | d_loss: 0.1245 | g_loss: 0.6628
# Epoch [   50/   50] | d_loss: 0.0673 | g_loss: 0.5211
# Epoch [   50/   50] | d_loss: 0.0734 | g_loss: 0.6360
# Epoch [   50/   50] | d_loss: 0.0671 | g_loss: 0.6219
# Epoch [   50/   50] | d_loss: 0.3351 | g_loss: 0.9569
# Epoch [   50/   50] | d_loss: 0.0920 | g_loss: 0.9421
# Epoch [   50/   50] | d_loss: 0.0928 | g_loss: 0.5721
# Epoch [   50/   50] | d_loss: 0.0867 | g_loss: 0.4469

# %% [markdown]
# ## Training loss
#
# Plot the training losses for the generator and discriminator, recorded after each epoch.

# %%
fig, ax = plt.subplots()
losses = np.array(losses)
plt.plot(losses.T[0], label='Discriminator', alpha=0.5)
plt.plot(losses.T[1], label='Generator', alpha=0.5)
plt.title("Training Losses")
plt.legend()

# %% [markdown]
# ## Generator samples from training
#
# View samples of images from the generator, and answer a question about the strengths and weaknesses of your trained models.

# %%
# helper function for viewing a list of passed in sample images
def view_samples(epoch, samples):
    fig, axes = plt.subplots(figsize=(16,4), nrows=2, ncols=8, sharey=True, sharex=True)
    for ax, img in zip(axes.flatten(), samples[epoch]):
        img = img.detach().cpu().numpy()
        img = np.transpose(img, (1, 2, 0))
        img = ((img + 1)*255 / (2)).astype(np.uint8)
        ax.xaxis.set_visible(False)
        ax.yaxis.set_visible(False)
        im = ax.imshow(img.reshape((32,32,3)))

# %%
# Load samples from generator, taken while training
with open('train_samples.pkl', 'rb') as f:
    samples = pkl.load(f)

# %%
_ = view_samples(-1, samples)

# %% [markdown]
# ### Question: What do you notice about your generated samples and how might you improve this model?
# When you answer this question, consider the following factors:
# * The dataset is biased; it is made of "celebrity" faces that are mostly white
# * Model size; larger models have the opportunity to learn more features in a data feature space
# * Optimization strategy; optimizers and number of epochs affect your final result

# %% [markdown]
# ## Answer:
#
# * There are formed generated faces that clearly depict characteristics of a face (nose, eyes, eyebrows etc). I feel as if these images would be clearer if the model had more epochs to train. I only trained for 50 epcohs so maybe an additional 20 epochs would show significant improvement.
#
#
# * Also to address the issue of bias of the celebrity faces that are majority white, we could improve the training data by adding more faces of celebrities of different races.

# %% [markdown]
# ### Submitting This Project
# When submitting this project, make sure to run all the cells before saving the notebook. Save the notebook file as "dlnd_face_generation.ipynb" and save it as a HTML file under "File" -> "Download as". Include the "problem_unittests.py" files in your submission.
